# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/GCN-HAR/source/st-gcn-tam.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/GCN-HAR/source/st-gcn-tam-demo.zip
#    creating: /content/st-gcn-tam/
#    creating: /content/st-gcn-tam/.git/
#   inflating: /content/st-gcn-tam/.git/config
#   inflating: /content/st-gcn-tam/.git/description
#  extracting: /content/st-gcn-tam/.git/HEAD
#    creating: /content/st-gcn-tam/.git/hooks/
#   inflating: /content/st-gcn-tam/.git/hooks/applypatch-msg.sample
#   inflating: /content/st-gcn-tam/.git/hooks/commit-msg.sample
#   inflating: /content/st-gcn-tam/.git/hooks/fsmonitor-watchman.sample
#   inflating: /content/st-gcn-tam/.git/hooks/post-update.sample
#   inflating: /content/st-gcn-tam/.git/hooks/pre-applypatch.sample
#   inflating: /content/st-gcn-tam/.git/hooks/pre-commit.sample
#   inflating: /content/st-gcn-tam/.git/hooks/pre-merge-commit.sample
#   inflating: /content/st-gcn-tam/.git/hooks/pre-push.sample
#   inflating: /content/st-gcn-tam/.git/hooks/pre-rebase.sample
#   inflating: /content/st-gcn-tam/.git/hooks/pre-receive.sample
# ...

# %%
# %cd /content
# Out:
# /content

# %%
# %cd st-gcn-tam
# %cd torchlight
# !python setup.py install
# %cd ..
# Out:
# /content/st-gcn-tam
# /content/st-gcn-tam/torchlight
# running install
# running bdist_egg
# running egg_info
# creating torchlight.egg-info
# writing torchlight.egg-info/PKG-INFO
# writing dependency_links to torchlight.egg-info/dependency_links.txt
# writing top-level names to torchlight.egg-info/top_level.txt
# writing manifest file 'torchlight.egg-info/SOURCES.txt'
# writing manifest file 'torchlight.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/torchlight
# copying torchlight/gpu.py -> build/lib/torchlight
# copying torchlight/__init__.py -> build/lib/torchlight
# copying torchlight/io.py -> build/lib/torchlight
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/torchlight
# copying build/lib/torchlight/gpu.py -> build/bdist.linux-x86_64/egg/torchlight
# ...

# %%
# %cd ..
# Out:
# /content

# %%
# !mkdir /content/st-gcn-tam/data

# %% [markdown]
# ## Tải dữ liệu

# %%
# !unzip /content/drive/MyDrive/GCN-HAR/NTU-RGB+D/preprocess/NTU-RGB-D.zip -d /content/st-gcn-tam/data
# Out:
# Archive:  /content/drive/MyDrive/GCN-HAR/NTU-RGB+D/preprocess/NTU-RGB-D.zip
#    creating: /content/st-gcn-tam/data/NTU-RGB-D/
#    creating: /content/st-gcn-tam/data/NTU-RGB-D/xsub/
#   inflating: /content/st-gcn-tam/data/NTU-RGB-D/xsub/train_data.npy
#   inflating: /content/st-gcn-tam/data/NTU-RGB-D/xsub/train_label.pkl
#   inflating: /content/st-gcn-tam/data/NTU-RGB-D/xsub/val_data.npy
#   inflating: /content/st-gcn-tam/data/NTU-RGB-D/xsub/val_label.pkl
#    creating: /content/st-gcn-tam/data/NTU-RGB-D/xview/
#   inflating: /content/st-gcn-tam/data/NTU-RGB-D/xview/train_data.npy
#   inflating: /content/st-gcn-tam/data/NTU-RGB-D/xview/train_label.pkl
#   inflating: /content/st-gcn-tam/data/NTU-RGB-D/xview/val_data.npy
#   inflating: /content/st-gcn-tam/data/NTU-RGB-D/xview/val_label.pkl

# %% [markdown]
# ## Cài đặt môi trường

# %%
# %cd /content
# Out:
# /content

# %%
# %cd /content/st-gcn-tam
# Out:
# /content/st-gcn-tam

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.3 MB 53.3 MB/s
# ...

# %%
# !pip install -U PyYAML
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 596 kB 33.8 MB/s
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# %cd /content/st-gcn-tam
# Out:
# /content/st-gcn-tam

# %% [markdown]
# ## Huấn luyện

# %%
# !python main.py recognition -c config/st_gcn/ntu-xview/train.yaml --work_dir /content/drive/MyDrive/GCN-HAR/work_dir_tam/ --work_dir /content/drive/MyDrive/GCN-HAR/work_dir_tam/ --weights /content/drive/MyDrive/GCN-HAR/work_dir_tam/epoch60_model.pt --start_epoch 60
# Out:
# [07.19.22|07:34:18] Load weights from /content/drive/MyDrive/GCN-HAR/work_dir_tam/epoch60_model.pt.
# [07.19.22|07:34:28] Load weights [A].
# [07.19.22|07:34:28] Load weights [data_bn.weight].
# [07.19.22|07:34:28] Load weights [data_bn.bias].
# [07.19.22|07:34:28] Load weights [data_bn.running_mean].
# [07.19.22|07:34:28] Load weights [data_bn.running_var].
# [07.19.22|07:34:28] Load weights [data_bn.num_batches_tracked].
# [07.19.22|07:34:28] Load weights [st_gcn_networks.0.gcn.conv.weight].
# [07.19.22|07:34:28] Load weights [st_gcn_networks.0.gcn.conv.bias].
# [07.19.22|07:34:28] Load weights [st_gcn_networks.0.tcn.0.weight].
# [07.19.22|07:34:28] Load weights [st_gcn_networks.0.tcn.0.bias].
# [07.19.22|07:34:28] Load weights [st_gcn_networks.0.tcn.0.running_mean].
# [07.19.22|07:34:28] Load weights [st_gcn_networks.0.tcn.0.running_var].
# [07.19.22|07:34:28] Load weights [st_gcn_networks.0.tcn.0.num_batches_tracked].
# ...
