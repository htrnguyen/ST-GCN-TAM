# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/GCN-HAR/source/st-gcn-tam-demo.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/GCN-HAR/source/st-gcn-tam-demo.zip
#    creating: /content/st-gcn-tam/
#    creating: /content/st-gcn-tam/.git/
#   inflating: /content/st-gcn-tam/.git/config
#   inflating: /content/st-gcn-tam/.git/description
#  extracting: /content/st-gcn-tam/.git/HEAD
#    creating: /content/st-gcn-tam/.git/hooks/
#   inflating: /content/st-gcn-tam/.git/hooks/applypatch-msg.sample
#   inflating: /content/st-gcn-tam/.git/hooks/commit-msg.sample
#   inflating: /content/st-gcn-tam/.git/hooks/fsmonitor-watchman.sample
#   inflating: /content/st-gcn-tam/.git/hooks/post-update.sample
#   inflating: /content/st-gcn-tam/.git/hooks/pre-applypatch.sample
#   inflating: /content/st-gcn-tam/.git/hooks/pre-commit.sample
#   inflating: /content/st-gcn-tam/.git/hooks/pre-merge-commit.sample
#   inflating: /content/st-gcn-tam/.git/hooks/pre-push.sample
#   inflating: /content/st-gcn-tam/.git/hooks/pre-rebase.sample
#   inflating: /content/st-gcn-tam/.git/hooks/pre-receive.sample
# ...

# %%
# %cd /content
# Out:
# /content

# %%
# %cd st-gcn-tam
# %cd torchlight
# !python setup.py install
# %cd ..
# Out:
# /content/st-gcn-tam
# /content/st-gcn-tam/torchlight
# running install
# running bdist_egg
# running egg_info
# creating torchlight.egg-info
# writing torchlight.egg-info/PKG-INFO
# writing dependency_links to torchlight.egg-info/dependency_links.txt
# writing top-level names to torchlight.egg-info/top_level.txt
# writing manifest file 'torchlight.egg-info/SOURCES.txt'
# writing manifest file 'torchlight.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/torchlight
# copying torchlight/__init__.py -> build/lib/torchlight
# copying torchlight/gpu.py -> build/lib/torchlight
# copying torchlight/io.py -> build/lib/torchlight
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/torchlight
# copying build/lib/torchlight/__init__.py -> build/bdist.linux-x86_64/egg/torchlight
# ...

# %%
# %cd ..
# Out:
# /content

# %% [markdown]
# ## Cài đặt môi trường

# %%
# %cd /content
# Out:
# /content

# %%
# %cd /content/st-gcn-tam
# Out:
# /content/st-gcn-tam

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.3 MB 6.9 MB/s
# ...

# %%
# !pip install -U PyYAML
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 596 kB 5.3 MB/s
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %% [markdown]
# # demo

# %%
# !python demo.py demo --skeleton /content/st-gcn-tam/data_demo/S001C001P001R001A001.skeleton
# Out:
# Chuan hoa khung xuong dau vao
# Lap lai cac khung phia truoc
# 100% 1/1 [00:00<00:00, 1882.54it/s]
# chuan hoa trong tam
# 100% 1/1 [00:00<00:00, 3708.49it/s]
# chuan hoa xuong cot song
# 100% 1/1 [00:00<00:00, 57.75it/s]
# chuan hoa 2 khop vai
# 100% 1/1 [00:00<00:00, 57.18it/s]
#
# Lan truyen qua kien truc...
# Chuan hoa du lieu
# Lan truyen tien qua mang
# Ket noi day du
# Ket qua nhan dang: A1. drink water.
# Hoan thanh.
# truc quan khung xuong goc
# Hoan thanh.
# Luu ket qua
# Hoan thanh
